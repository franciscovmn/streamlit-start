# %%
import pandas as pd

# %%
compra_itens = pd.read_csv('compra_itens.csv', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 compra_itens = pd.read_csv('compra_itens.csv', delimiter=';')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'compra_itens.csv'

# %%
venda_itens = pd.read_csv('venda_itens.csv', delimiter=';', encoding='latin1')

# %%
produtos = pd.read_csv('produto.csv', sep=';', encoding='latin1')

# %%
compras = pd.read_csv('compra.csv', delimiter=';')

# %%
fornecedores = pd.read_csv('fornecedores.csv', delimiter=';', encoding='latin-1')

# %%
vendas=pd.read_csv('venda.csv', delimiter=';', encoding='latin-1')

# %%
clientes=pd.read_csv('clientes.csv', delimiter=';', encoding='latin-1')

# %%
venda_cliente = pd.merge(vendas[['FLOJA','IDPEDIDO','IDCLI','SI_CAIXA','FDATAEMI','HORA','FVALVENDA']],clientes[['IDFORN','NOMEFORN']],how='left',left_on='IDCLI',right_on='IDFORN')
venda_cliente.rename(columns= {'NOMEFORN': 'NOMECLI'}, inplace=True)
venda_cliente.drop('IDFORN', axis='columns')
del venda_cliente['IDFORN']

# %%
venda_cliente['NOMECLI'].fillna('Consumidor final', inplace=True)
venda_cliente
# Out:
#      FLOJA     IDPEDIDO  IDCLI  SI_CAIXA    FDATAEMI   HORA  FVALVENDA  \
# 0        1   V24246C831    831         1  08/01/2023  09:10     319.84
# 1        1  V24252C1736   1736         1  08/01/2023  14:20    1100.00
# 2        1  V24258C1119   1119         1  08/01/2023  16:54     750.00
# 3        1  V24260C1336   1336         1  08/02/2023  08:12    2090.00
# 4        1   V24264C831    831         1  08/02/2023  08:48    5979.96
# ..     ...          ...    ...       ...         ...    ...        ...
# 97       1  V24538C1794   1794         1  08/28/2023  11:20      84.00
# 98       1  V24547C1390   1390         1  08/29/2023  09:40     800.00
# 99       1   V24550C516    516         1  08/29/2023  10:35      57.34
# 100      1  V24551C1798   1798         1  08/29/2023  10:51    1875.51
# 101      1  V24552C1798   1798         1  08/29/2023  10:52    1875.51
#
#               NOMECLI
# 0     SHOPPING DOS CO
# 1    Consumidor final
# 2     QUALITECH TECNO
# 3    Consumidor final
# 4     SHOPPING DOS CO
# ..                ...
# 97   Consumidor final
# 98   Consumidor final
# 99     POSTO OPCAO JD
# 100  Consumidor final
# 101  Consumidor final
#
# [102 rows x 8 columns]

# %%
forn_831 = venda_cliente['IDCLI'] == 831

# %%
forn_831_2 = venda_cliente.query('IDCLI == 831 ')
forn_831_2.head()
# Out:
#     FLOJA    IDPEDIDO  IDCLI  SI_CAIXA    FDATAEMI   HORA  FVALVENDA  \
# 0       1  V24246C831    831         1  08/01/2023  09:10     319.84
# 4       1  V24264C831    831         1  08/02/2023  08:48    5979.96
# 8       1  V24271C831    831         1  08/02/2023  10:26    3751.90
# 9       1  V24272C831    831         1  08/02/2023  10:26    3751.90
# 17      1  V24297C831    831         1  08/03/2023  16:12    4704.60
#
#             NOMECLI
# 0   SHOPPING DOS CO
# 4   SHOPPING DOS CO
# 8   SHOPPING DOS CO
# 9   SHOPPING DOS CO
# 17  SHOPPING DOS CO

# %%
#o drop permite que os index resetados fiquem fixos, e nao em  uma coluna posterios
forn_831_2.reset_index(drop=True)
# Out:
#     FLOJA    IDPEDIDO  IDCLI  SI_CAIXA    FDATAEMI   HORA  FVALVENDA  \
# 0       1  V24246C831    831         1  08/01/2023  09:10     319.84
# 1       1  V24264C831    831         1  08/02/2023  08:48    5979.96
# 2       1  V24271C831    831         1  08/02/2023  10:26    3751.90
# 3       1  V24272C831    831         1  08/02/2023  10:26    3751.90
# 4       1  V24297C831    831         1  08/03/2023  16:12    4704.60
# 5       1  V24298C831    831         1  08/03/2023  16:13    4704.60
# 6       1  V24249C831    831         1  08/07/2023  14:53   17285.56
# 7       1  V24339C831    831         1  08/07/2023  15:45   36726.10
# 8       1  V24408C831    831         1  08/10/2023  16:12   41269.40
# 9       1  V24410C831    831         1  08/10/2023  16:28   23250.24
# 10      1  V24426C831    831         1  08/11/2023  16:28     338.20
#
#             NOMECLI
# 0   SHOPPING DOS CO
# 1   SHOPPING DOS CO
# 2   SHOPPING DOS CO
# 3   SHOPPING DOS CO
# 4   SHOPPING DOS CO
# 5   SHOPPING DOS CO
# 6   SHOPPING DOS CO
# 7   SHOPPING DOS CO
# 8   SHOPPING DOS CO
# 9   SHOPPING DOS CO
# 10  SHOPPING DOS CO

# %%
venda_cliente.query('IDCLI == 831 and FVALVENDA > 1000' )
# Out:
#     FLOJA    IDPEDIDO  IDCLI  SI_CAIXA    FDATAEMI   HORA  FVALVENDA  \
# 4       1  V24264C831    831         1  08/02/2023  08:48    5979.96
# 8       1  V24271C831    831         1  08/02/2023  10:26    3751.90
# 9       1  V24272C831    831         1  08/02/2023  10:26    3751.90
# 17      1  V24297C831    831         1  08/03/2023  16:12    4704.60
# 18      1  V24298C831    831         1  08/03/2023  16:13    4704.60
# 35      1  V24249C831    831         1  08/07/2023  14:53   17285.56
# 36      1  V24339C831    831         1  08/07/2023  15:45   36726.10
# 59      1  V24408C831    831         1  08/10/2023  16:12   41269.40
# 60      1  V24410C831    831         1  08/10/2023  16:28   23250.24
#
#             NOMECLI
# 4   SHOPPING DOS CO
# 8   SHOPPING DOS CO
# 9   SHOPPING DOS CO
# 17  SHOPPING DOS CO
# 18  SHOPPING DOS CO
# 35  SHOPPING DOS CO
# 36  SHOPPING DOS CO
# 59  SHOPPING DOS CO
# 60  SHOPPING DOS CO

# %%
selecao_1 = (venda_cliente['IDCLI'] == 831) | (venda_cliente['IDCLI'] == 516)
selecao_2 = (venda_cliente['FVALVENDA'] > 100)
selecao_final = selecao_1 & selecao_2
venda_cliente[selecao_final].reset_index(drop=True)
# Out:
#     FLOJA    IDPEDIDO  IDCLI  SI_CAIXA    FDATAEMI   HORA  FVALVENDA  \
# 0       1  V24246C831    831         1  08/01/2023  09:10     319.84
# 1       1  V24264C831    831         1  08/02/2023  08:48    5979.96
# 2       1  V24271C831    831         1  08/02/2023  10:26    3751.90
# 3       1  V24272C831    831         1  08/02/2023  10:26    3751.90
# 4       1  V24297C831    831         1  08/03/2023  16:12    4704.60
# 5       1  V24298C831    831         1  08/03/2023  16:13    4704.60
# 6       1  V24249C831    831         1  08/07/2023  14:53   17285.56
# 7       1  V24339C831    831         1  08/07/2023  15:45   36726.10
# 8       1  V24408C831    831         1  08/10/2023  16:12   41269.40
# 9       1  V24410C831    831         1  08/10/2023  16:28   23250.24
# 10      1  V24426C831    831         1  08/11/2023  16:28     338.20
# 11      1  V24427C516    516         1  08/14/2023  09:38    1000.00
#
#             NOMECLI
# 0   SHOPPING DOS CO
# 1   SHOPPING DOS CO
# 2   SHOPPING DOS CO
# 3   SHOPPING DOS CO
# 4   SHOPPING DOS CO
# 5   SHOPPING DOS CO
# 6   SHOPPING DOS CO
# 7   SHOPPING DOS CO
# 8   SHOPPING DOS CO
# 9   SHOPPING DOS CO
# 10  SHOPPING DOS CO
# 11   POSTO OPCAO JD

# %%
lista_clientes = [831,1736,1119]
clientes_teste = venda_cliente.query('IDCLI in @lista_clientes').reset_index(drop=True)

# %%
for index, row in clientes_teste.head(10).iterrows():
    print(f'indice {index} => {row["NOMECLI"]}')
# Out:
# indice 0 => SHOPPING DOS CO
# indice 1 => Consumidor final
# indice 2 => QUALITECH TECNO
# indice 3 => SHOPPING DOS CO
# indice 4 => SHOPPING DOS CO
# indice 5 => SHOPPING DOS CO
# indice 6 => SHOPPING DOS CO
# indice 7 => SHOPPING DOS CO
# indice 8 => SHOPPING DOS CO
# indice 9 => SHOPPING DOS CO

# %%
produto_mais_venda = venda_itens.groupby('PCOD')['VLVENDA'].sum().reset_index()
produto_mais_venda = produto_mais_venda.sort_values(by='VLVENDA', ascending=False)
produto_mais_venda
# Out:
#     PCOD   VLVENDA
# 53  4870  94488.66
# 45  4108  39600.00
# 14   291  18560.32
# 61  5042  17451.96
# 21   375  11946.00
# ..   ...       ...
# 52  4806    105.29
# 0    144     84.00
# 39  3465     82.26
# 22   481     80.00
# 48  4525     80.00
#
# [78 rows x 2 columns]

# %%
# Criando tabela dos produtos que mais venderam
produto_mais_venda = venda_itens.groupby('PCOD')['VLVENDA'].sum().reset_index()

# Localizando os produtos que mais venderam
produto_mais_venda = produto_mais_venda.sort_values(by='VLVENDA', ascending=False)

# Selecionando os top 5 produtos que mais venderam
top_produtos_mais_vendidos = produto_mais_venda.head(5)

# Agora mesclando para saber o nome dos produtos
verifica_nome_produtos_vendas = top_produtos_mais_vendidos.merge(produtos[['PCOD', 'PDESC', 'PUNIDADE', 'PVLUVENDA' , 'PVLUVEN3']], on='PCOD')

verifica_nome_produtos_vendas
# Out:
#    PCOD   VLVENDA                           PDESC PUNIDADE  PVLUVENDA  \
# 0  4870  94488.66  ESCORA METALICA 31O SEM CANECA       PC     143.70
# 1  4108  39600.00     ESCORA METALICA 31O CM MD L       PC     227.30
# 2   291  18560.32  GIRICA CH14 REF ROLAMENTO/ ESF     UNID    1556.00
# 3  5042  17451.96          FORCADO DUPLO P/ TORRE       PC     116.01
# 4   375  11946.00        VIGA METALICA V8 2.00 MT       PC     274.19
#
#    PVLUVEN3
# 0     87.66
# 1    118.07
# 2    554.39
# 3     58.90
# 4    110.41
